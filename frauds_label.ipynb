# %%
import pandas as pd
from tqdm import tqdm
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
#First of all, import these data for processing
col_names_B = ['Rndrng_NPI', 'Rndrng_Prvdr_Gndr', 'Rndrng_Prvdr_Type','Rndrng_Prvdr_State_FIPS', 'Tot_HCPCS_Cds','Tot_Benes', 'Tot_Srvcs', 'Tot_Sbmtd_Chrg', 'Tot_Mdcr_Pymt_Amt', 'Bene_Avg_Risk_Scre']
col_names_D = ['PRSCRBR_NPI', 'Prscrbr_Gndr','Prscrbr_Type', 'Prscrbr_State_FIPS','Tot_Clms', 'Tot_30day_Fills', 'Tot_Day_Suply', 'Tot_Drug_Cst', 'Tot_Benes']
col_names_DMEPOS = ['Rfrg_NPI', 'Rfrg_Prvdr_Gndr', 'Rfrg_Prvdr_Type', 'Rfrg_Prvdr_State_FIPS','Tot_Suplrs', 'Tot_Suplr_HCPCS_Cds','Tot_Suplr_Benes', 'Tot_Suplr_Clms', 'Tot_Suplr_Srvcs', 'Suplr_Sbmtd_Chrgs', 'Suplr_Mdcr_Pymt_Amt']

# %%
#import the part B data of 2021
Part_B_data_2021 = pd.read_csv('Medicare_Physician_Other_Practitioners_by_Provider_2021.csv',sep=',',usecols=col_names_B)
Part_B_data_df_2021 = pd.DataFrame(Part_B_data_2021).iloc[1:].reset_index(drop=True)
Part_B_data_df_2021
# Out:
# /var/folders/gm/vdq6g76x11l24y8k6gvx9kgm0000gn/T/ipykernel_79761/1194424780.py:2: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   Part_B_data_2021 = pd.read_csv('Medicare_Physician_Other_Practitioners_by_Provider_2021.csv',sep=',',usecols=col_names_B)
#          Rndrng_NPI Rndrng_Prvdr_Gndr Rndrng_Prvdr_State_FIPS  \
# 0        1003000134                 M                      17
# 1        1003000142                 M                      39
# 2        1003000423                 F                      39
# 3        1003000480                 M                      08
# 4        1003000530                 F                      42
# ...             ...               ...                     ...
# 1198748  1992999569                 F                       6
# 1198749  1992999585                 M                      42
# 1198750  1992999775               NaN                      41
# ...

# %%
#import the part B data of 2020
Part_B_data_2020 = pd.read_csv('Medicare_Physician_Other_Practitioners_by_Provider_2020.csv',sep=',',usecols=col_names_B,encoding='ISO-8859-1')
Part_B_data_df_2020 = pd.DataFrame(Part_B_data_2020).iloc[1:].reset_index(drop=True)
Part_B_data_df_2020
# Out:
# /var/folders/gm/vdq6g76x11l24y8k6gvx9kgm0000gn/T/ipykernel_79761/1361943881.py:2: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   Part_B_data_2020 = pd.read_csv('Medicare_Physician_Other_Practitioners_by_Provider_2020.csv',sep=',',usecols=col_names_B,encoding='ISO-8859-1')
#          Rndrng_NPI Rndrng_Prvdr_Gndr Rndrng_Prvdr_State_FIPS  \
# 0        1003000134                 M                      17
# 1        1003000142                 M                      39
# 2        1003000423                 F                      39
# 3        1003000480                 M                      08
# 4        1003000522                 M                      12
# ...             ...               ...                     ...
# 1161536  1992999551                 F                      06
# 1161537  1992999585                 M                      42
# 1161538  1992999775               NaN                      41
# ...

# %%
#import the part B data of 2019 
Part_B_data_2019 = pd.read_csv('Medicare_Physician_Other_Practitioners_by_Provider_2019.csv',sep=',',usecols=col_names_B,encoding='ISO-8859-1')
Part_B_data_df_2019 = pd.DataFrame(Part_B_data_2019).iloc[1:].reset_index(drop=True)
Part_B_data_df_2019
# Out:
#          Rndrng_NPI Rndrng_Prvdr_Gndr  Rndrng_Prvdr_State_FIPS  \
# 0        1003000134                 M                     17.0
# 1        1003000142                 M                     39.0
# 2        1003000423                 F                     39.0
# 3        1003000480                 M                      8.0
# 4        1003000522                 M                     12.0
# ...             ...               ...                      ...
# 1155864  1992999569                 F                      6.0
# 1155865  1992999759                 M                     13.0
# 1155866  1992999775               NaN                     41.0
# 1155867  1992999825                 M                     53.0
# 1155868  1992999874                 F                     51.0
#
#                   Rndrng_Prvdr_Type  Tot_HCPCS_Cds  Tot_Benes  Tot_Srvcs  \
# 0                         Pathology             20       3614     7835.0
# ...

# %%
#import the list of doctors who involved in fraudulent activities in 2021
fraud_data_df_2021 = pd.read_csv('fraud_Data_2021.csv', index_col=0)
fraud_data_df_2021
# Out:
#           FIRSTNAME MIDNAME                      BUSNAME  \
# LASTNAME
# NaN             NaN     NaN  101 FIRST CARE PHARMACY INC
# NaN             NaN     NaN   A PERFECT FIT FOR YOU, INC
# NaN             NaN     NaN    ACCESS 2 INTEGRATION, INC
# NaN             NaN     NaN    ACUTE CARE OF NEVADA, LLC
# NaN             NaN     NaN     AFFORDABLE PHARMACY, INC
# ...             ...     ...                          ...
# HENRY         JIMMY     NaN                          NaN
# HENRY         SHAWN    MARK                          NaN
# HERBERGER    ROBERT     NaN                          NaN
# HERNANDEZ   GABRIEL     NaN                          NaN
# HERNANDEZ    MILENA  MENZUI                          NaN
#
#                         GENERAL             SPECIALTY UPIN         NPI  \
# LASTNAME
# NaN              OTHER BUSINESS              PHARMACY  NaN  1972902351
# NaN                 DME COMPANY         DME - GENERAL  NaN  1265830335
# ...

# %%
#import the list of doctors who involved in fraudulent activities in 2020
fraud_data_df_2020 = pd.read_csv('fraud_Data_2020.csv', index_col=0)
fraud_data_df_2020
# Out:
#           FIRSTNAME MIDNAME                      BUSNAME  \
# LASTNAME
# NaN             NaN     NaN  101 FIRST CARE PHARMACY INC
# NaN             NaN     NaN   A PERFECT FIT FOR YOU, INC
# NaN             NaN     NaN    ACCESS 2 INTEGRATION, INC
# NaN             NaN     NaN    ACUTE CARE OF NEVADA, LLC
# NaN             NaN     NaN     AFFORDABLE PHARMACY, INC
# ...             ...     ...                          ...
# HENRY         SHAWN    MARK                          NaN
# HENSON       STEVEN       R                          NaN
# HERBERGER    ROBERT     NaN                          NaN
# HERNANDEZ   GABRIEL     NaN                          NaN
# HERNANDEZ    MILENA  MENZUI                          NaN
#
#                         GENERAL             SPECIALTY UPIN         NPI  \
# LASTNAME
# NaN              OTHER BUSINESS              PHARMACY  NaN  1972902351
# NaN                 DME COMPANY         DME - GENERAL  NaN  1265830335
# ...

# %%
#import the list of doctors who involved in fraudulent activities in 2019
fraud_data_df_2019 = pd.read_csv('fraud_Data_2019.csv', index_col=0)
fraud_data_df_2019
# Out:
#           FIRSTNAME MIDNAME                         BUSNAME  \
# LASTNAME
# NaN             NaN     NaN     101 FIRST CARE PHARMACY INC
# NaN             NaN     NaN      A PERFECT FIT FOR YOU, INC
# NaN             NaN     NaN  ACACIA MENTAL HEALTH CLINIC, L
# NaN             NaN     NaN       ACCESS 2 INTEGRATION, INC
# NaN             NaN     NaN       ACUTE CARE OF NEVADA, LLC
# ...             ...     ...                             ...
# HENRY         SHAWN    MARK                             NaN
# HENSON       STEVEN       R                             NaN
# HERBERGER    ROBERT     NaN                             NaN
# HERNANDEZ   GABRIEL     NaN                             NaN
# HERNANDEZ    MILENA  MENZUI                             NaN
#
#                         GENERAL             SPECIALTY UPIN         NPI  \
# LASTNAME
# NaN              OTHER BUSINESS              PHARMACY  NaN  1972902351
# NaN                 DME COMPANY         DME - GENERAL  NaN  1265830335
# ...

# %%
#Generate the LSIT of the NPI in the LEIE dataset of each year
list_of_2021_fraud_data = fraud_data_df_2021['NPI'].values.tolist()
list_of_2020_fraud_data = fraud_data_df_2020['NPI'].values.tolist()
list_of_2019_fraud_data = fraud_data_df_2019['NPI'].values.tolist()

# %%
#Label Part B dataset of 2021
Part_B_data_df_2021['Exclusion'] = 0

for index, row in tqdm(Part_B_data_df_2021.iterrows()):
    if row['Rndrng_NPI'] in list_of_2021_fraud_data:
        Part_B_data_df_2021.at[index, 'Exclusion'] = 1
# Out:
# 1198753it [00:30, 39491.87it/s]

# %%
#Label Part B dataset of 2020
Part_B_data_df_2020['Exclusion'] = 0

for index, row in tqdm(Part_B_data_df_2020.iterrows()):
    if row['Rndrng_NPI'] in list_of_2020_fraud_data:
        Part_B_data_df_2020.at[index, 'Exclusion'] = 1
# Out:
# 1161541it [00:32, 35935.67it/s]

# %%
#Label Part B dataset of 2019
Part_B_data_df_2019['Exclusion'] = 0

for index, row in tqdm(Part_B_data_df_2019.iterrows()):
    if row['Rndrng_NPI'] in list_of_2019_fraud_data:
        Part_B_data_df_2019.at[index, 'Exclusion'] = 1
# Out:
# 1155869it [00:35, 32680.47it/s]

# %%
#Sum the number of fraud labels in the data of 2021 
labeled_number = sum(Part_B_data_df_2021['Exclusion'] == 1)
labeled_number
# Out:
# 36

# %%
print(Part_B_data_df_2020.columns)
# Out:
# Index(['Rndrng_NPI', 'Rndrng_Prvdr_Gndr', 'Rndrng_Prvdr_State_FIPS',
#        'Rndrng_Prvdr_Type', 'Tot_HCPCS_Cds', 'Tot_Benes', 'Tot_Srvcs',
#        'Tot_Sbmtd_Chrg', 'Tot_Mdcr_Pymt_Amt', 'Bene_Avg_Risk_Scre',
#        'Exclusion'],
#       dtype='object')

# %%
#Sum the number of fraud labels in the data of 2020
labeled_number = sum(Part_B_data_df_2020['Exclusion'] == 1)
labeled_number
# Out:
# 88

# %%
#Sum the number of fraud labels in the data of 2019
labeled_number = sum(Part_B_data_df_2019['Exclusion'] == 1)
labeled_number
# Out:
# 161

# %%
#Save the Part B dataset of 2021 after fraud labeling 
Part_B_data_df_2021.to_csv('Part_B_data_of_2021_with_fraudabel.csv', index = False)

# %%
#Save the Part B dataset of 2020 after fraud labeling 
Part_B_data_df_2020.to_csv('Part_B_data_of_2020_with_fraudabel.csv', index = False)

# %%
#Save the Part B dataset of 2019 after fraud labeling 
Part_B_data_df_2019.to_csv('Part_B_data_of_2019_with_fraudabel.csv', index = False)

# %%
#import the part D data of 2021
Part_D_data_2021 = pd.read_csv('Medicare_Part_D_Prescribers_by_Provider_2021.csv',sep=',',usecols=col_names_D,encoding='ISO-8859-1')
Part_D_data_df_2021 = pd.DataFrame(Part_D_data_2021).iloc[1:].reset_index(drop=True)
#remove some symbols in Part D dataset of 2021
Part_D_data_df_2021.replace('$','',regex=False)
Part_D_data_df_2021
# Out:
#          PRSCRBR_NPI Prscrbr_Gndr  Prscrbr_State_FIPS  \
# 0         1003000142            M                39.0
# 1         1003000167            M                32.0
# 2         1003000175            F                 6.0
# 3         1003000423            F                39.0
# 4         1003000480            M                 8.0
# ...              ...          ...                 ...
# 1287448   1992999650            M                25.0
# 1287449   1992999692            F                39.0
# 1287450   1992999817            M                 6.0
# 1287451   1992999825            M                53.0
# 1287452   1992999874            F                51.0
#
#                     Prscrbr_Type  Tot_Clms  Tot_30day_Fills  Tot_Drug_Cst  \
# 0                 Anesthesiology      1493      1619.766667      37841.04
# 1                        Dentist        47        47.666667        221.66
# 2                        Dentist        20        20.000000        125.82
# ...

# %%
#import the part D data of 2020
Part_D_data_2020 = pd.read_csv('Medicare_Part_D_Prescribers_by_Provider_2020.csv',sep=',',usecols=col_names_D,encoding='ISO-8859-1')
Part_D_data_df_2020 = pd.DataFrame(Part_D_data_2020).iloc[1:].reset_index(drop=True)
#remove some symbols in Part D dataset of 2020
Part_D_data_df_2020.replace('$','',regex=False)
Part_D_data_df_2020
# Out:
#          PRSCRBR_NPI Prscrbr_Gndr  Prscrbr_State_FIPS  \
# 0         1003000142            M                39.0
# 1         1003000167            M                32.0
# 2         1003000175            F                 6.0
# 3         1003000282            F                47.0
# 4         1003000423            F                39.0
# ...              ...          ...                 ...
# 1255169   1992999569            F                 6.0
# 1255170   1992999650            M                25.0
# 1255171   1992999759            M                13.0
# 1255172   1992999825            M                53.0
# 1255173   1992999874            F                51.0
#
#                     Prscrbr_Type  Tot_Clms  Tot_30day_Fills  Tot_Drug_Cst  \
# 0                 Anesthesiology      1992      2145.666667      79803.65
# 1                        Dentist        57        57.700000        327.34
# 2                        Dentist        18        18.000000        128.52
# ...

# %%
#import the part D data of 2019
Part_D_data_2019 = pd.read_csv('Medicare_Part_D_Prescribers_by_Provider_2019.csv',sep=',',usecols=col_names_D,encoding='ISO-8859-1')
Part_D_data_df_2019 = pd.DataFrame(Part_D_data_2019).iloc[1:].reset_index(drop=True)
#remove some symbols in Part D dataset of 2019
Part_D_data_df_2019.replace('$','',regex=False)
Part_D_data_df_2019
# Out:
#          PRSCRBR_NPI Prscrbr_Gndr  Prscrbr_State_FIPS        Prscrbr_Type  \
# 0         1003000142            M                39.0      Anesthesiology
# 1         1003000167            M                32.0             Dentist
# 2         1003000175            F                 6.0             Dentist
# 3         1003000282            F                47.0  Nurse Practitioner
# 4         1003000407            M                42.0     Family Practice
# ...              ...          ...                 ...                 ...
# 1240589   1992999759            M                13.0  Nurse Practitioner
# 1240590   1992999817            M                 6.0  Orthopedic Surgery
# 1240591   1992999825            M                53.0      Otolaryngology
# 1240592   1992999833            M                36.0       Psychoanalyst
# 1240593   1992999874            F                51.0   Internal Medicine
#
#          Tot_Clms  Tot_30day_Fills  Tot_Drug_Cst  Tot_Day_Suply  Tot_Benes
# ...

# %%
#Transform the type of 2021 Part D dataset
list_1 = {3,5,6,7,8,9}
for i in range(7):
    if i in list_1:
        Part_D_data_df_2021[col_names_D[i]] = Part_D_data_df_2021[col_names_D[i]].astype('double')

#Replace NaNs with the median in the Part D dataset of 2021
Part_D_data_df_2021.fillna(Part_D_data_df_2021.median(), inplace = True)
Part_D_data_df_2021
# Out:
# /var/folders/gm/vdq6g76x11l24y8k6gvx9kgm0000gn/T/ipykernel_79761/552344630.py:8: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Part_D_data_df_2021.fillna(Part_D_data_df_2021.median(), inplace = True)
#          PRSCRBR_NPI Prscrbr_Gndr  Prscrbr_State_FIPS  \
# 0         1003000142            M                39.0
# 1         1003000167            M                32.0
# 2         1003000175            F                 6.0
# 3         1003000423            F                39.0
# 4         1003000480            M                 8.0
# ...              ...          ...                 ...
# 1287448   1992999650            M                25.0
# 1287449   1992999692            F                39.0
# 1287450   1992999817            M                 6.0
# 1287451   1992999825            M                53.0
# ...

# %%
#Transform the type of 2020 Part D dataset
list_1 = {3,5,6,7,8,9}
for i in range(7):
    if i in list_1:
        Part_D_data_df_2020[col_names_D[i]] = Part_D_data_df_2020[col_names_D[i]].astype('double')

#Replace NaNs with the median in the Part D dataset of 2020
Part_D_data_df_2020.fillna(Part_D_data_df_2020.median(), inplace = True)
Part_D_data_df_2020
# Out:
# /var/folders/gm/vdq6g76x11l24y8k6gvx9kgm0000gn/T/ipykernel_79761/1329205854.py:8: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Part_D_data_df_2020.fillna(Part_D_data_df_2020.median(), inplace = True)
#          PRSCRBR_NPI Prscrbr_Gndr  Prscrbr_State_FIPS  \
# 0         1003000142            M                39.0
# 1         1003000167            M                32.0
# 2         1003000175            F                 6.0
# 3         1003000282            F                47.0
# 4         1003000423            F                39.0
# ...              ...          ...                 ...
# 1255169   1992999569            F                 6.0
# 1255170   1992999650            M                25.0
# 1255171   1992999759            M                13.0
# 1255172   1992999825            M                53.0
# ...

# %%
#Transform the type of 2019 Part D dataset
list_1 = {3,5,6,7,8,9}
for i in range(7):
    if i in list_1:
        Part_D_data_df_2019[col_names_D[i]] = Part_D_data_df_2019[col_names_D[i]].astype('double')

#Replace NaNs with the median in the Part D dataset of 2019
Part_D_data_df_2019.fillna(Part_D_data_df_2019.median(), inplace = True)
Part_D_data_df_2019
# Out:
# /var/folders/gm/vdq6g76x11l24y8k6gvx9kgm0000gn/T/ipykernel_79761/3332472117.py:8: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   Part_D_data_df_2019.fillna(Part_D_data_df_2019.median(), inplace = True)
#          PRSCRBR_NPI Prscrbr_Gndr  Prscrbr_State_FIPS        Prscrbr_Type  \
# 0         1003000142            M                39.0      Anesthesiology
# 1         1003000167            M                32.0             Dentist
# 2         1003000175            F                 6.0             Dentist
# 3         1003000282            F                47.0  Nurse Practitioner
# 4         1003000407            M                42.0     Family Practice
# ...              ...          ...                 ...                 ...
# 1240589   1992999759            M                13.0  Nurse Practitioner
# ...

# %%
#import DMEPOS data of 2021        
DMEPOS_data_2021 = pd.read_csv('Medicare_Durable_Medical_Equipment_Devices_Supplies_by_Referring_Provider_Data_2021.csv', sep=',', usecols = col_names_DMEPOS,encoding='ISO-8859-1')
DMEPOS_data_df_2021 = pd.DataFrame(DMEPOS_data_2021).iloc[1:].reset_index(drop=True)
DMEPOS_data_df_2021
# Out:
# /var/folders/gm/vdq6g76x11l24y8k6gvx9kgm0000gn/T/ipykernel_79761/1851929967.py:2: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   DMEPOS_data_2021 = pd.read_csv('Medicare_Durable_Medical_Equipment_Devices_Supplies_by_Referring_Provider_Data_2021.csv', sep=',', usecols = col_names_DMEPOS,encoding='ISO-8859-1')
#           Rfrg_NPI Rfrg_Prvdr_Gndr Rfrg_Prvdr_State_FIPS    Rfrg_Prvdr_Type  \
# 0       1003000480               M                     8    General Surgery
# 1       1003000522               M                    12    Family Practice
# 2       1003000530               F                    42  Internal Medicine
# 3       1003000597               M                    40            Urology
# 4       1003000902               F                    21    Family Practice
# ...            ...             ...                   ...                ...
# 384258  1992998645               F                    48  Internal Medicine
# ...

# %%
#Transform the type of 2021 DMEPOS dataset
list_2 = {3,4,5,6,7,8}
for j in range(9):
    if j in list_2:
        DMEPOS_data_df_2021[col_names_DMEPOS[j]] = pd.to_numeric(
            DMEPOS_data_df_2021[col_names_DMEPOS[j]], errors='coerce'
        )
#Replace NaNs with the median in the DMEPOS dataset of 2021       
DMEPOS_data_df_2021.fillna(DMEPOS_data_df_2021.median(), inplace = True)
DMEPOS_data_df_2021
# Out:
# /var/folders/gm/vdq6g76x11l24y8k6gvx9kgm0000gn/T/ipykernel_79761/3321150614.py:9: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   DMEPOS_data_df_2021.fillna(DMEPOS_data_df_2021.median(), inplace = True)
#           Rfrg_NPI Rfrg_Prvdr_Gndr  Rfrg_Prvdr_State_FIPS    Rfrg_Prvdr_Type  \
# 0       1003000480               M                    8.0    General Surgery
# 1       1003000522               M                   12.0    Family Practice
# 2       1003000530               F                   42.0  Internal Medicine
# 3       1003000597               M                   40.0            Urology
# 4       1003000902               F                   21.0    Family Practice
# ...            ...             ...                    ...                ...
# ...

# %%
#import DMEPOS data of 2020        
DMEPOS_data_2020 = pd.read_csv('Medicare_Durable_Medical_Equipment_Devices_Supplies_by_Referring_Provider_Data_2020.csv', sep=',', usecols = col_names_DMEPOS,encoding='ISO-8859-1')
DMEPOS_data_df_2020 = pd.DataFrame(DMEPOS_data_2020).iloc[1:].reset_index(drop=True)
DMEPOS_data_df_2020
# Out:
# /var/folders/gm/vdq6g76x11l24y8k6gvx9kgm0000gn/T/ipykernel_79761/3050043224.py:2: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   DMEPOS_data_2020 = pd.read_csv('Medicare_Durable_Medical_Equipment_Devices_Supplies_by_Referring_Provider_Data_2020.csv', sep=',', usecols = col_names_DMEPOS,encoding='ISO-8859-1')
#           Rfrg_NPI Rfrg_Prvdr_Gndr Rfrg_Prvdr_State_FIPS      Rfrg_Prvdr_Type  \
# 0       1003000522               M                    12      Family Practice
# 1       1003000530               F                    42    Internal Medicine
# 2       1003000597               M                    40              Urology
# 3       1003000738               F                    48  Physician Assistant
# 4       1003000902               F                    21      Family Practice
# ...            ...             ...                   ...                  ...
# ...

# %%
#Transform the type of 2020 DMEPOS dataset
list_2 = {3,4,5,6,7,8}
for j in range(9):
    if j in list_2:
        DMEPOS_data_df_2020[col_names_DMEPOS[j]] = pd.to_numeric(
            DMEPOS_data_df_2020[col_names_DMEPOS[j]], errors='coerce'
        )
#Replace NaNs with the median in the DMEPOS dataset of 2020       
DMEPOS_data_df_2020.fillna(DMEPOS_data_df_2020.median(), inplace = True)
DMEPOS_data_df_2020
# Out:
# /var/folders/gm/vdq6g76x11l24y8k6gvx9kgm0000gn/T/ipykernel_79761/2535688816.py:9: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   DMEPOS_data_df_2020.fillna(DMEPOS_data_df_2020.median(), inplace = True)
#           Rfrg_NPI Rfrg_Prvdr_Gndr  Rfrg_Prvdr_State_FIPS  \
# 0       1003000522               M                   12.0
# 1       1003000530               F                   42.0
# 2       1003000597               M                   40.0
# 3       1003000738               F                   48.0
# 4       1003000902               F                   21.0
# ...            ...             ...                    ...
# 383482  1992998645               F                   48.0
# 383483  1992998736               M                   12.0
# 383484  1992999122               M                   12.0
# ...

# %%
#import DMEPOS data of 2019       
DMEPOS_data_2019 = pd.read_csv('Medicare_Durable_Medical_Equipment_Devices_Supplies_by_Referring_Provider_Data_2019.csv', sep=',', usecols = col_names_DMEPOS,encoding='ISO-8859-1')
DMEPOS_data_df_2019 = pd.DataFrame(DMEPOS_data_2019).iloc[1:].reset_index(drop=True)
DMEPOS_data_df_2019
# Out:
# /var/folders/gm/vdq6g76x11l24y8k6gvx9kgm0000gn/T/ipykernel_79761/3034090753.py:2: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   DMEPOS_data_2019 = pd.read_csv('Medicare_Durable_Medical_Equipment_Devices_Supplies_by_Referring_Provider_Data_2019.csv', sep=',', usecols = col_names_DMEPOS,encoding='ISO-8859-1')
#           Rfrg_NPI Rfrg_Prvdr_Gndr Rfrg_Prvdr_State_FIPS      Rfrg_Prvdr_Type  \
# 0       1003000522               M                    12      Family Practice
# 1       1003000530               F                    42    Internal Medicine
# 2       1003000597               M                    40              Urology
# 3       1003000902               F                    21      Family Practice
# 4       1003001363               M                     6      Pain Management
# ...            ...             ...                   ...                  ...
# ...

# %%
#Transform the type of 2019 DMEPOS dataset
list_2 = {3,4,5,6,7,8}
for j in range(9):
    if j in list_2:
        DMEPOS_data_df_2019[col_names_DMEPOS[j]] = pd.to_numeric(
            DMEPOS_data_df_2019[col_names_DMEPOS[j]], errors='coerce'
        )
#Replace NaNs with the median in the DMEPOS dataset of 2019        
DMEPOS_data_df_2019.fillna(DMEPOS_data_df_2019.median(), inplace = True)
DMEPOS_data_df_2019
# Out:
# /var/folders/gm/vdq6g76x11l24y8k6gvx9kgm0000gn/T/ipykernel_79761/1656835161.py:9: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   DMEPOS_data_df_2019.fillna(DMEPOS_data_df_2019.median(), inplace = True)
#           Rfrg_NPI Rfrg_Prvdr_Gndr  Rfrg_Prvdr_State_FIPS  \
# 0       1003000522               M                   12.0
# 1       1003000530               F                   42.0
# 2       1003000597               M                   40.0
# 3       1003000902               F                   21.0
# 4       1003001363               M                    6.0
# ...            ...             ...                    ...
# 389304  1992998736               M                   12.0
# 389305  1992999122               M                   12.0
# 389306  1992999270               F                   12.0
# ...

# %%
Part_D_data_df_2021.to_csv('Part_D_data_of_2021_with_fraudabel.csv', index = False)
Part_D_data_df_2020.to_csv('Part_D_data_of_2020_with_fraudabel.csv', index = False)
Part_D_data_df_2019.to_csv('Part_D_data_of_2019_with_fraudabel.csv', index = False)

# %%
DMEPOS_data_df_2021.to_csv('DMEPOS_of_2021_with_fraudabel.csv', index = False)
DMEPOS_data_df_2020.to_csv('DMEPOS_of_2020_with_fraudabel.csv', index = False)
DMEPOS_data_df_2019.to_csv('DMEPOS_of_2019_with_fraudabel.csv', index = False)

# %%
Part_B_data_df_2019.isnull().sum()
# Out:
# Rndrng_NPI                     0
# Rndrng_Prvdr_Gndr          59929
# Rndrng_Prvdr_State_FIPS      817
# Rndrng_Prvdr_Type              0
# Tot_HCPCS_Cds                  0
# Tot_Benes                      0
# Tot_Srvcs                      0
# Tot_Sbmtd_Chrg                 0
# Tot_Mdcr_Pymt_Amt              0
# Bene_Avg_Risk_Scre             0
# Exclusion                      0
# dtype: int64

# %%
#One-hot Encodeing was performed on the dataset
# Correct column names for one-hot encoding
columns_to_encode = ['Rndrng_Prvdr_Gndr', 'Rndrng_Prvdr_Type']

# Perform one-hot encoding
Part_B_data_df_2019 = pd.get_dummies(Part_B_data_df_2019, columns=columns_to_encode)

# %%
Part_B_data_df_2019
# Out:
#          Rndrng_NPI  Rndrng_Prvdr_State_FIPS  Tot_HCPCS_Cds  Tot_Benes  \
# 0        1003000134                     17.0             20       3614
# 1        1003000142                     39.0             54        264
# 2        1003000423                     39.0             24         74
# 3        1003000480                      8.0             30        104
# 4        1003000522                     12.0             46        374
# ...             ...                      ...            ...        ...
# 1155864  1992999569                      6.0              8         16
# 1155865  1992999759                     13.0             29         35
# 1155866  1992999775                     41.0             17        164
# 1155867  1992999825                     53.0             40        535
# 1155868  1992999874                     51.0              9         56
#
#          Tot_Srvcs  Tot_Sbmtd_Chrg  Tot_Mdcr_Pymt_Amt  Bene_Avg_Risk_Scre  \
# ...

# %%
#One-hot Encodeing was performed on the dataset
# Correct column names for one-hot encoding
columns_to_encode = ['Rndrng_Prvdr_Gndr', 'Rndrng_Prvdr_Type']

# Perform one-hot encoding
Part_B_data_df_2020 = pd.get_dummies(Part_B_data_df_2020, columns=columns_to_encode)

# %%
Part_B_data_df_2020
# Out:
#          Rndrng_NPI Rndrng_Prvdr_State_FIPS  Tot_HCPCS_Cds  Tot_Benes  \
# 0        1003000134                      17             18       2633
# 1        1003000142                      39             54        167
# 2        1003000423                      39             21         56
# 3        1003000480                      08             30         89
# 4        1003000522                      12             34        251
# ...             ...                     ...            ...        ...
# 1161536  1992999551                      06             40        333
# 1161537  1992999585                      42              2         66
# 1161538  1992999775                      41             21        159
# 1161539  1992999825                      53             46        456
# 1161540  1992999874                      51             15        407
#
#          Tot_Srvcs  Tot_Sbmtd_Chrg  Tot_Mdcr_Pymt_Amt  Bene_Avg_Risk_Scre  \
# ...

# %%
#One-hot Encodeing was performed on the dataset
# Correct column names for one-hot encoding
columns_to_encode = ['Rndrng_Prvdr_Gndr', 'Rndrng_Prvdr_Type']

# Perform one-hot encoding
Part_B_data_df_2021 = pd.get_dummies(Part_B_data_df_2021, columns=columns_to_encode)

# %%
Part_B_data_df_2021
# Out:
#          Rndrng_NPI Rndrng_Prvdr_State_FIPS  Tot_HCPCS_Cds  Tot_Benes  \
# 0        1003000134                      17             21       3216
# 1        1003000142                      39             52        239
# 2        1003000423                      39             19         69
# 3        1003000480                      08             29        112
# 4        1003000530                      42             31        404
# ...             ...                     ...            ...        ...
# 1198748  1992999569                       6              6         19
# 1198749  1992999585                      42              2         18
# 1198750  1992999775                      41             22        180
# 1198751  1992999825                      53             40        359
# 1198752  1992999874                      51             12        355
#
#          Tot_Srvcs  Tot_Sbmtd_Chrg  Tot_Mdcr_Pymt_Amt  Bene_Avg_Risk_Scre  \
# ...

# %%
#Save the datasets after all features have been processed
Part_B_data_df_2019.to_csv('Part_B_data_of_2019_with_finallabel.csv', index = False)
Part_B_data_df_2020.to_csv('Part_B_data_of_2020_with_finallabel.csv', index = False)
Part_B_data_df_2021.to_csv('Part_B_data_of_2021_with_finallabel.csv', index = False)

# %%
data_frames = [Part_B_data_df_2021, Part_B_data_df_2020, Part_B_data_df_2019,
               Part_D_data_df_2021, Part_D_data_df_2020, Part_D_data_df_2019,
               DMEPOS_data_df_2021, DMEPOS_data_df_2020, DMEPOS_data_df_2019]

for df in data_frames:
    df.rename(columns={'Rndrng_NPI': 'NPI', 'PRSCRBR_NPI': 'NPI', 'Rfrg_NPI': 'NPI'}, inplace=True)

# %%
data_frames = [Part_D_data_df_2021, Part_D_data_df_2020, Part_D_data_df_2019,
               DMEPOS_data_df_2021, DMEPOS_data_df_2020, DMEPOS_data_df_2019]

columns_to_drop = ['Prscrbr_Gndr', 'Prscrbr_Type', 'Rfrg_Prvdr_Gndr', 'Rfrg_Prvdr_Type']

for df in data_frames:
    for col in columns_to_drop:
        if col in df.columns:
            df.drop(columns=col, inplace=True)

# %%
if 'NPI' in Part_B_data_df_2021.columns and 'NPI' in Part_D_data_df_2021.columns:
    data_combine_2021 = pd.merge(Part_B_data_df_2021, Part_D_data_df_2021, on='NPI')
else:
    print("The 'NPI' column does not exist in one or both of the DataFrames.")

# %%
#Combine the Part B & Part D dataset of 2021 based on NPI criteria
data_combine_2021 = pd.merge(Part_B_data_df_2021, Part_D_data_df_2021, on = 'NPI')

# %%
#Combine the merged dataset 2021 & DMEPOS dataset of 2021 based on NPI criteria
data_combine_of_2021 = pd.merge(data_combine_2021, DMEPOS_data_df_2021, on = 'NPI')

# %%
data_combine_of_2021
# Out:
#                NPI Rndrng_Prvdr_State_FIPS  Tot_HCPCS_Cds  Tot_Benes_x  \
# 0       1003000480                      08             29          112
# 1       1003000530                      42             31          404
# 2       1003000597                      40            117          852
# 3       1003000902                      21             29          276
# 4       1003000936                      45             68          996
# ...            ...                     ...            ...          ...
# 333717  1992998645                      48             30          329
# 333718  1992998736                      12             47          144
# 333719  1992999122                      12             35         1251
# 333720  1992999551                       6             31          301
# 333721  1992999874                      51             12          355
#
#         Tot_Srvcs  Tot_Sbmtd_Chrg  Tot_Mdcr_Pymt_Amt  Bene_Avg_Risk_Scre  \
# ...

# %%
#Combine the Part B & Part D dataset of 2020 based on NPI criteria
data_combine_2020 = pd.merge(Part_B_data_df_2020, Part_D_data_df_2020, on = 'NPI')
#Combine the merged dataset 2020 & DMEPOS dataset of 2020 based on NPI criteria
data_combine_of_2020 = pd.merge(data_combine_2020, DMEPOS_data_df_2020, on = 'NPI')

# %%
data_combine_of_2020
# Out:
#                NPI Rndrng_Prvdr_State_FIPS  Tot_HCPCS_Cds  Tot_Benes_x  \
# 0       1003000522                      12             34          251
# 1       1003000530                      42             35          359
# 2       1003000597                      40             92          739
# 3       1003000902                      21             43          285
# 4       1003000936                      45             73          972
# ...            ...                     ...            ...          ...
# 334383  1992998645                      48             37          365
# 334384  1992998736                      12             50          138
# 334385  1992999122                      12             34         1215
# 334386  1992999551                      06             40          333
# 334387  1992999874                      51             15          407
#
#         Tot_Srvcs  Tot_Sbmtd_Chrg  Tot_Mdcr_Pymt_Amt  Bene_Avg_Risk_Scre  \
# ...

# %%
#Combine the Part B & Part D dataset of 2019 based on NPI criteria
data_combine_2019 = pd.merge(Part_B_data_df_2019, Part_D_data_df_2019, on = 'NPI')
#Combine the merged dataset 2019 & DMEPOS dataset of 2019 based on NPI criteria
data_combine_of_2019 = pd.merge(data_combine_2019, DMEPOS_data_df_2019, on = 'NPI')

# %%
data_combine_of_2019
# Out:
#                NPI  Rndrng_Prvdr_State_FIPS  Tot_HCPCS_Cds  Tot_Benes_x  \
# 0       1003000522                     12.0             46          374
# 1       1003000530                     42.0             33          347
# 2       1003000597                     40.0            117          796
# 3       1003000902                     21.0             34          316
# 4       1003001363                      6.0             50         1106
# ...            ...                      ...            ...          ...
# 343163  1992998736                     12.0             43          130
# 343164  1992999122                     12.0             35         1320
# 343165  1992999270                     12.0             28          108
# 343166  1992999551                      6.0             44          408
# 343167  1992999759                     13.0             29           35
#
#         Tot_Srvcs  Tot_Sbmtd_Chrg  Tot_Mdcr_Pymt_Amt  Bene_Avg_Risk_Scre  \
# ...

# %%
#Save the combined dataset
data_combine_of_2019.to_csv('combined_dataset_2019.csv', index = False)
data_combine_of_2020.to_csv('combined_dataset_2020.csv', index = False)
data_combine_of_2021.to_csv('combined_dataset_2021.csv', index = False)
